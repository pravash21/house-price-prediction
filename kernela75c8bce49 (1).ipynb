# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
#sns.set_style('whitegrid')
# %matplotlib inline

# Machine Learning 
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import statistics as st
import haversine
from shapely.geometry import Point
from shapely.geometry import shape, Point
from shapely.geometry.polygon import Polygon
from shapely.geometry import MultiPoint

# %%
os.listdir('../input')

# %%
with open('../input/houseprice/poi.json') as f:
    poi = json.load(f)

# %%
d = pd.read_csv('../input/houseprice/heatmap.csv')

# %%
lat = d['latitude']
lon = d['longitude']
purc = d['weight']

# %%
print(poi[100])

# %%
transit_station=[]
department_store=[]
administrative_area_level_1=[]
subway_station=[]
synagogue=[]
train_station=[]
post_box=[]
postal_code_suffix=[]
meal_takeaway=[]
physiotherapist=[]
neighborhood=[]
postal_code=[]
accounting=[]
museum=[]
post_office=[]
car_repair=[]
city_hall=[]
funeral_home=[]
atm=[]
library=[]
casino=[]
street_address=[]
lodging=[]
home_goods_store=[]
storage=[]
natural_feature=[]
painter=[]
amusement_park=[]
sublocality_level_2=[]
geocode=[]
political=[]
fire_station=[]
floor=[]
place_of_worship=[]
plumber=[]
route=[]
real_estate_agency=[]
clothing_store=[]
electronics_store=[]
sublocality_level_3=[]
store=[]
movie_theater=[]
street_number=[]
gas_station=[]
locksmith=[]
gym=[]
convenience_store=[]
general_contractor=[]
shoe_store=[]
premise=[]
lawyer=[]
subpremise=[]
beauty_salon=[]
local_government_office=[]
park=[]
bar=[]
bus_station=[]
restaurant=[]
hardware_store=[]
electrician=[]
insurance_agency=[]
bicycle_store=[]
school=[]
hospital=[]
taxi_stand=[]
art_gallery=[]
night_club=[]
postal_code_prefix=[]
health=[]
travel_agency=[]
campground=[]
sublocality=[]
book_store=[]
sublocality_level_5=[]
jewelry_store=[]
colloquial_area=[]
finance=[]
car_wash=[]
administrative_area_level_3=[]
establishment=[]
bowling_alley=[]
roofing_contractor=[]
administrative_area_level_4=[]
dentist=[]
sublocality_level_4=[]
mosque=[]
zoo=[]
church=[]
parking=[]
locality=[]
bakery=[]
cemetery=[]
postal_town=[]
hindu_temple=[]
movie_rental=[]
pharmacy=[]
rv_park=[]
liquor_store=[]
aquarium=[]
supermarket=[]
veterinary_care=[]
airport=[]
spa=[]
food=[]
car_rental=[]
laundry=[]
pet_store=[]
embassy=[]
meal_delivery=[]
administrative_area_level_5=[]
car_dealer=[]
room=[]
point_of_interest=[]
intersection=[]
cafe=[]
doctor=[]
hair_care=[]
country=[]
bank=[]
florist=[]
moving_company=[]
stadium=[]
furniture_store=[]
courthouse=[]
sublocality_level_1=[]
administrative_area_level_2=[]
shopping_mall=[]
police=[]

# %%
ind=[0]*32682
for i in range(32682):
    ind[i]=i

# %%
df = pd.DataFrame(columns=['transit_station','department_store',
'administrative_area_level_1',
'subway_station',
'synagogue',
'train_station',
'post_box',
'postal_code_suffix',
'meal_takeaway',
'physiotherapist',
'neighborhood',
'postal_code',
'accounting',
'museum',
'post_office',
'car_repair',
'city_hall',
'funeral_home',
'atm',
'library',
'casino',
'street_address',
'lodging',
'home_goods_store',
'storage',
'natural_feature',
'painter',
'amusement_park',
'sublocality_level_2',
'geocode',
'political',
'fire_station',
'floor',
'place_of_worship',
'plumber',
'route',
'real_estate_agency',
'clothing_store',
'electronics_store',
'sublocality_level_3',
'store',
'movie_theater',
'street_number',
'gas_station',
'locksmith',
'gym',
'convenience_store',
'general_contractor',
'shoe_store',
'premise',
'lawyer',
'subpremise',
'beauty_salon',
'local_government_office',
'park',
'bar',
'bus_station',
'restaurant',
'hardware_store',
'electrician',
'insurance_agency',
'bicycle_store',
'school',
'hospital',
'taxi_stand',
'art_gallery',
'night_club',
'postal_code_prefix',
'health',
'travel_agency',
'campground',
'sublocality',
'book_store',
'sublocality_level_5',
'jewelry_store',
'colloquial_area',
'finance',
'car_wash',
'administrative_area_level_3',
'establishment',
'bowling_alley',
'roofing_contractor',
'administrative_area_level_4',
'dentist',
'sublocality_level_4',
'mosque',
'zoo',
'church',
'parking',
'locality',
'bakery',
'cemetery',
'postal_town',
'hindu_temple',
'movie_rental',
'pharmacy',
'rv_park',
'liquor_store',
'aquarium',
'supermarket',
'veterinary_care',
'airport',
'spa',
'food',
'car_rental',
'laundry',
'pet_store',
'embassy',
'meal_delivery',
'administrative_area_level_5',
'car_dealer',
'room',
'point_of_interest',
'intersection',
'cafe',
'doctor',
'hair_care',
'country',
'bank',
'florist',
'moving_company',
'stadium',
'furniture_store',
'courthouse',
'sublocality_level_1',
'administrative_area_level_2',
'shopping_mall',
'police','price'], index = ind)

# %%
for i in range(len(lat)):
    transit_station=[0]
    department_store=[0]
    administrative_area_level_1=[0]
    subway_station=[0]
    synagogue=[0]
    train_station=[0]
    post_box=[0]
    postal_code_suffix=[0]
    meal_takeaway=[0]
    physiotherapist=[0]
    neighborhood=[0]
    postal_code=[0]
    accounting=[0]
    museum=[0]
    post_office=[0]
    car_repair=[0]
    city_hall=[0]
    funeral_home=[0]
    atm=[0]
    library=[0]
    casino=[0]
    street_address=[0]
    lodging=[0]
    home_goods_store=[0]
    storage=[0]
    natural_feature=[0]
    painter=[0]
    amusement_park=[0]
    sublocality_level_2=[0]
    geocode=[0]
    political=[0]
    fire_station=[0]
    floor=[0]
    place_of_worship=[0]
    plumber=[0]
    route=[0]
    real_estate_agency=[0]
    clothing_store=[0]
    electronics_store=[0]
    sublocality_level_3=[0]
    store=[0]
    movie_theater=[0]
    street_number=[0]
    gas_station=[0]
    locksmith=[0]
    gym=[0]
    convenience_store=[0]
    general_contractor=[0]
    shoe_store=[0]
    premise=[0]
    lawyer=[0]
    subpremise=[0]
    beauty_salon=[0]
    local_government_office=[0]
    park=[0]
    bar=[0]
    bus_station=[0]
    restaurant=[0]
    hardware_store=[0]
    electrician=[0]
    insurance_agency=[0]
    bicycle_store=[0]
    school=[0]
    hospital=[0]
    taxi_stand=[0]
    art_gallery=[0]
    night_club=[0]
    postal_code_prefix=[0]
    health=[0]
    travel_agency=[0]
    campground=[0]
    sublocality=[0]
    book_store=[0]
    sublocality_level_5=[0]
    jewelry_store=[0]
    colloquial_area=[0]
    finance=[0]
    car_wash=[0]
    administrative_area_level_3=[0]
    establishment=[0]
    bowling_alley=[0]
    roofing_contractor=[0]
    administrative_area_level_4=[0]
    dentist=[0]
    sublocality_level_4=[0]
    mosque=[0]
    zoo=[0]
    church=[0]
    parking=[0]
    locality=[0]
    bakery=[0]
    cemetery=[0]
    postal_town=[0]
    hindu_temple=[0]
    movie_rental=[0]
    pharmacy=[0]
    rv_park=[0]
    liquor_store=[0]
    aquarium=[0]
    supermarket=[0]
    veterinary_care=[0]
    airport=[0]
    spa=[0]
    food=[0]
    car_rental=[0]
    laundry=[0]
    pet_store=[0]
    embassy=[0]
    meal_delivery=[0]
    administrative_area_level_5=[0]
    car_dealer=[0]
    room=[0]
    point_of_interest=[0]
    intersection=[0]
    cafe=[0]
    doctor=[0]
    hair_care=[0]
    country=[0]
    bank=[0]
    florist=[0]
    moving_company=[0]
    stadium=[0]
    furniture_store=[0]
    courthouse=[0]
    sublocality_level_1=[0]
    administrative_area_level_2=[0]
    shopping_mall=[0]
    police=[0]
    point = Point(lon[i],lat[i])
    for j in range(len(poi)):
        y=poi[j]['geometry']
        polygon = shape(y)
        k=point.distance(polygon)*1000
        #print(k)
        if(k<=200):
            transit_station.append(poi[j]['transit_station'])
            department_store.append(poi[j]['department_store'])
            administrative_area_level_1.append(poi[j]['administrative_area_level_1'])
            subway_station.append(poi[j]['subway_station'])
            synagogue.append(poi[j]['synagogue'])
            train_station.append(poi[j]['train_station'])
            post_box.append(poi[j]['post_box'])
            postal_code_suffix.append(poi[j]['postal_code_suffix'])
            meal_takeaway.append(poi[j]['meal_takeaway'])
            physiotherapist.append(poi[j]['physiotherapist'])
            neighborhood.append(poi[j]['neighborhood'])
            postal_code.append(poi[j]['postal_code'])
            accounting.append(poi[j]['accounting'])
            museum.append(poi[j]['museum'])
            post_office.append(poi[j]['post_office'])
            car_repair.append(poi[j]['car_repair'])
            city_hall.append(poi[j]['city_hall'])
            funeral_home.append(poi[j]['funeral_home'])
            atm.append(poi[j]['atm'])
            library.append(poi[j]['library'])
            casino.append(poi[j]['casino'])
            street_address.append(poi[j]['street_address'])
            lodging.append(poi[j]['lodging'])
            home_goods_store.append(poi[j]['home_goods_store'])
            storage.append(poi[j]['storage'])
            natural_feature.append(poi[j]['natural_feature'])
            painter.append(poi[j]['painter'])
            amusement_park.append(poi[j]['amusement_park'])
            sublocality_level_2.append(poi[j]['sublocality_level_2'])
            geocode.append(poi[j]['geocode'])
            political.append(poi[j]['political'])
            fire_station.append(poi[j]['fire_station'])
            floor.append(poi[j]['floor'])
            place_of_worship.append(poi[j]['place_of_worship'])
            plumber.append(poi[j]['plumber'])
            route.append(poi[j]['route'])
            real_estate_agency.append(poi[j]['real_estate_agency'])
            clothing_store.append(poi[j]['clothing_store'])
            electronics_store.append(poi[j]['electronics_store'])
            sublocality_level_3.append(poi[j]['sublocality_level_3'])
            store.append(poi[j]['store'])
            movie_theater.append(poi[j]['movie_theater'])
            street_number.append(poi[j]['street_number'])
            gas_station.append(poi[j]['gas_station'])
            locksmith.append(poi[j]['locksmith'])
            gym.append(poi[j]['gym'])
            convenience_store.append(poi[j]['convenience_store'])
            general_contractor.append(poi[j]['general_contractor'])
            shoe_store.append(poi[j]['shoe_store'])
            premise.append(poi[j]['premise'])
            lawyer.append(poi[j]['lawyer'])
            subpremise.append(poi[j]['subpremise'])
            beauty_salon.append(poi[j]['beauty_salon'])
            local_government_office.append(poi[j]['local_government_office'])
            park.append(poi[j]['park'])
            bar.append(poi[j]['bar'])
            bus_station.append(poi[j]['bus_station'])
            restaurant.append(poi[j]['restaurant'])
            hardware_store.append(poi[j]['hardware_store'])
            electrician.append(poi[j]['electrician'])
            insurance_agency.append(poi[j]['insurance_agency'])
            bicycle_store.append(poi[j]['bicycle_store'])
            school.append(poi[j]['school'])
            hospital.append(poi[j]['hospital'])
            taxi_stand.append(poi[j]['taxi_stand'])
            art_gallery.append(poi[j]['art_gallery'])
            night_club.append(poi[j]['night_club'])
            postal_code_prefix.append(poi[j]['postal_code_prefix'])
            health.append(poi[j]['health'])
            travel_agency.append(poi[j]['travel_agency'])
            campground.append(poi[j]['campground'])
            sublocality.append(poi[j]['sublocality'])
            book_store.append(poi[j]['book_store'])
            sublocality_level_5.append(poi[j]['sublocality_level_5'])
            jewelry_store.append(poi[j]['jewelry_store'])
            colloquial_area.append(poi[j]['colloquial_area'])
            finance.append(poi[j]['finance'])
            car_wash.append(poi[j]['car_wash'])
            administrative_area_level_3.append(poi[j]['administrative_area_level_3'])
            establishment.append(poi[j]['establishment'])
            bowling_alley.append(poi[j]['bowling_alley'])
            roofing_contractor.append(poi[j]['roofing_contractor'])
            administrative_area_level_4.append(poi[j]['administrative_area_level_4'])
            dentist.append(poi[j]['dentist'])
            sublocality_level_4.append(poi[j]['sublocality_level_4'])
            mosque.append(poi[j]['mosque'])
            zoo.append(poi[j]['zoo'])
            church.append(poi[j]['church'])
            parking.append(poi[j]['parking'])
            locality.append(poi[j]['locality'])
            bakery.append(poi[j]['bakery'])
            cemetery.append(poi[j]['cemetery'])
            postal_town.append(poi[j]['postal_town'])
            hindu_temple.append(poi[j]['hindu_temple'])
            movie_rental.append(poi[j]['movie_rental'])
            pharmacy.append(poi[j]['pharmacy'])
            rv_park.append(poi[j]['rv_park'])
            liquor_store.append(poi[j]['liquor_store'])
            aquarium.append(poi[j]['aquarium'])
            supermarket.append(poi[j]['supermarket'])
            veterinary_care.append(poi[j]['veterinary_care'])
            airport.append(poi[j]['airport'])
            spa.append(poi[j]['spa'])
            food.append(poi[j]['food'])
            car_rental.append(poi[j]['car_rental'])
            laundry.append(poi[j]['laundry'])
            pet_store.append(poi[j]['pet_store'])
            embassy.append(poi[j]['embassy'])
            meal_delivery.append(poi[j]['meal_delivery'])
            administrative_area_level_5.append(poi[j]['administrative_area_level_5'])
            car_dealer.append(poi[j]['car_dealer'])
            room.append(poi[j]['room'])
            point_of_interest.append(poi[j]['point_of_interest'])
            intersection.append(poi[j]['intersection'])
            cafe.append(poi[j]['cafe'])
            doctor.append(poi[j]['doctor'])
            hair_care.append(poi[j]['hair_care'])
            country.append(poi[j]['country'])
            bank.append(poi[j]['bank'])
            florist.append(poi[j]['florist'])
            moving_company.append(poi[j]['moving_company'])
            stadium.append(poi[j]['stadium'])
            furniture_store.append(poi[j]['furniture_store'])
            courthouse.append(poi[j]['courthouse'])
            sublocality_level_1.append(poi[j]['sublocality_level_1'])
            administrative_area_level_2.append(poi[j]['administrative_area_level_2'])
            shopping_mall.append(poi[j]['shopping_mall'])
            police.append(poi[j]['police'])
    arr=[]
    arr.append(max(transit_station))
    arr.append(max(department_store))
    arr.append(max(administrative_area_level_1))
    arr.append(max(subway_station))
    arr.append(max(synagogue))
    arr.append(max(train_station))
    arr.append(max(post_box))
    arr.append(max(postal_code_suffix))
    arr.append(max(meal_takeaway))
    arr.append(max(physiotherapist))
    arr.append(max(neighborhood))
    arr.append(max(postal_code))
    arr.append(max(accounting))
    arr.append(max(museum))
    arr.append(max(post_office))
    arr.append(max(car_repair))
    arr.append(max(city_hall))
    arr.append(max(funeral_home))
    arr.append(max(atm))
    arr.append(max(library))
    arr.append(max(casino))
    arr.append(max(street_address))
    arr.append(max(lodging))
    arr.append(max(home_goods_store))
    arr.append(max(storage))
    arr.append(max(natural_feature))
    arr.append(max(painter))
    arr.append(max(amusement_park))
    arr.append(max(sublocality_level_2))
    arr.append(max(geocode))
    arr.append(max(political))
    arr.append(max(fire_station))
    arr.append(max(floor))
    arr.append(max(place_of_worship))
    arr.append(max(plumber))
    arr.append(max(route))
    arr.append(max(real_estate_agency))
    arr.append(max(clothing_store))
    arr.append(max(electronics_store))
    arr.append(max(sublocality_level_3))
    arr.append(max(store))
    arr.append(max(movie_theater))
    arr.append(max(street_number))
    arr.append(max(gas_station))
    arr.append(max(locksmith))
    arr.append(max(gym))
    arr.append(max(convenience_store))
    arr.append(max(general_contractor))
    arr.append(max(shoe_store))
    arr.append(max(premise))
    arr.append(max(lawyer))
    arr.append(max(subpremise))
    arr.append(max(beauty_salon))
    arr.append(max(local_government_office))
    arr.append(max(park))
    arr.append(max(bar))
    arr.append(max(bus_station))
    arr.append(max(restaurant))
    arr.append(max(hardware_store))
    arr.append(max(electrician))
    arr.append(max(insurance_agency))
    arr.append(max(bicycle_store))
    arr.append(max(school))
    arr.append(max(hospital))
    arr.append(max(taxi_stand))
    arr.append(max(art_gallery))
    arr.append(max(night_club))
    arr.append(max(postal_code_prefix))
    arr.append(max(health))
    arr.append(max(travel_agency))
    arr.append(max(campground))
    arr.append(max(sublocality))
    arr.append(max(book_store))
    arr.append(max(sublocality_level_5))
    arr.append(max(jewelry_store))
    arr.append(max(colloquial_area))
    arr.append(max(finance))
    arr.append(max(car_wash))
    arr.append(max(administrative_area_level_3))
    arr.append(max(establishment))
    arr.append(max(bowling_alley))
    arr.append(max(roofing_contractor))
    arr.append(max(administrative_area_level_4))
    arr.append(max(dentist))
    arr.append(max(sublocality_level_4))
    arr.append(max(mosque))
    arr.append(max(zoo))
    arr.append(max(church))
    arr.append(max(parking))
    arr.append(max(locality))
    arr.append(max(bakery))
    arr.append(max(cemetery))
    arr.append(max(postal_town))
    arr.append(max(hindu_temple))
    arr.append(max(movie_rental))
    arr.append(max(pharmacy))
    arr.append(max(rv_park))
    arr.append(max(liquor_store))
    arr.append(max(aquarium))
    arr.append(max(supermarket))
    arr.append(max(veterinary_care))
    arr.append(max(airport))
    arr.append(max(spa))
    arr.append(max(food))
    arr.append(max(car_rental))
    arr.append(max(laundry))
    arr.append(max(pet_store))
    arr.append(max(embassy))
    arr.append(max(meal_delivery))
    arr.append(max(administrative_area_level_5))
    arr.append(max(car_dealer))
    arr.append(max(room))
    arr.append(max(point_of_interest))
    arr.append(max(intersection))
    arr.append(max(cafe))
    arr.append(max(doctor))
    arr.append(max(hair_care))
    arr.append(max(country))
    arr.append(max(bank))
    arr.append(max(florist))
    arr.append(max(moving_company))
    arr.append(max(stadium))
    arr.append(max(furniture_store))
    arr.append(max(courthouse))
    arr.append(max(sublocality_level_1))
    arr.append(max(administrative_area_level_2))
    arr.append(max(shopping_mall))
    arr.append(max(police))
    arr.append(purc[i])
    #print((arr))
    df.loc[i]=arr

# %%
df1 = pd.read_csv('../input/newdata/new-data.csv')

# %%
df1=df1.iloc[:,1:]

# %%
df1.head()
# Out:
#    transit_station  department_store    ...      police      price
# 0                1                 1    ...           1  19.047619
# 1                1                 1    ...           1  28.000000
# 2                0                 0    ...           0  27.333334
# 3                1                 1    ...           1  22.838500
# 4                1                 1    ...           1  22.500000
#
# [5 rows x 129 columns]

# %%
X = df1.iloc[:, :129]
Y = df1["price"]

# %%
corr = df1.corr()
# Find correlated data columns using heatmaps
sns.heatmap(corr)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.30, random_state=10)

# %%
linear_model = LinearRegression()

# fit the model with input and corresponding output data
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
accuracy = linear_model.score(x_test,y_test)
print("Accuracy",(accuracy*100))
# Out:
# Accuracy 100.0

# %%
predicted_house_price = linear_model.predict(x_test)

# %%
predicted_dataframe = pd.DataFrame(
    {"Predicted_Prices": predicted_house_price, "Actual_Prices": y_test})

# %%
predicted_dataframe.head()
# Out:
#        Predicted_Prices  Actual_Prices
# 25493         3466.6667      3466.6667
# 2264            16.0000        16.0000
# 997             10.5000        10.5000
# 14646         2849.5496      2849.5496
# 15688         5889.6494      5889.6494

# %%
plt.scatter(y_test, predicted_house_price, color='black')
plt.show()

# %%
from IPython.display import HTML
import pandas as pd
import numpy as np

predicted_dataframe.to_csv('output.csv')

def create_download_link(title = "Download CSV file", filename = "output.csv"):  
    html = '<a href={filename}>{title}</a>'
    html = html.format(title=title,filename=filename)
    return HTML(html)

# create a link to download the dataframe which was saved with .to_csv method
create_download_link(filename='output.csv')
